# %% [markdown]
# <a href="https://colab.research.google.com/github/darshanjoshi16/MachineLearningPracticals/blob/main/Practical%203(Matplotlib%20Tutorial)/ML_Practical_3_MatPlotLib_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MatPlotLib Tutorial

# %% [markdown]
# # Basics of Matplotlib and Importing

# %%
#simple basic importing and sample code
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 6])
ypoints = np.array([0, 200])
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# # Plotting x and y points

# %% [markdown]
# **Draw a line in a diagram from position (1, 3) to position (8, 10):**

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# # Plotting Without Line

# %% [markdown]
# **Draw two points in the diagram, one at position (1, 3) and one in position (8, 10):**

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# # Default X-Points

# %% [markdown]
# **Plotting without x-points**

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10, 5, 7])
plt.plot(ypoints)
plt.show()

# %% [markdown]
# # Markers

# %% [markdown]
# **Mark each point with a circle**:

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o')
# OR
plt.plot(ypoints, marker = '*')
plt.show()
plt.plot(ypoints, 'o:r') # circle, dotted line, red
plt.show()

# %% [markdown]
# # Marker Size

# %% [markdown]
# **Set the size of the markers to 20:**

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o', ms = 20)
plt.show()

# %% [markdown]
# # Marker Color

# %% [markdown]
# **Set the EDGE color to red**:

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %% [markdown]
# **Set the FACE color to red:**

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()
